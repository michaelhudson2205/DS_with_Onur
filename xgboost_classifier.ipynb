# %% [markdown]
# Installed the following packages at the PowerShell Prompt:
# - python -m pip install --upgrade pip
# - pip install jupyter
# - pip install ipykernel
#
# Installed the following packages within this Jupyter Notebook, as seen in the cells below:
# - pip install xgboost
# - pip install scikit-learn
# - pip install pandas

# %%
# %%capture
# %pip install scikit-learn

# %%
# %%capture
# %pip install xgboost

# %%
# %%capture
% pip install pandas

# %% [markdown]
# <table>
# <tr>
# <td style="width:150px">
#     <img src="Mike_Matrix.png" alt="Mike Matrix" width="150"/>
# </td>
# <td>
#     This work is based on a tutorial I found on <a href="https://www.youtube.com/watch?v=NZdWhFkc7lQ">YouTube</a> by <span style="color:orange; font-weight:bold">Data Science with Onur</span>. You can find my files on my <a href="https://github.com/michaelhudson2205/CarInsurance">GitHub</a>. The data used in this project is generated using <span style="font-weight: bold; font-style: italic;">sklearn.datasets.make_classification</span>, see link below.
# </td>
# </tr>
# <tr>
# <td>
# Medium Article:
# </td>
# <td>
# <a href="https://medium.com/analytics-vidhya/stratified-sampling-in-machine-learning-f5112b5b9cfe">Stratified sampling in Machine Learning</a>
# </td>
# </tr>
# <tr>
# <td>
# Medium Article:
# </td>
# <td>
# <a href="https://medium.com/@kyawsawhtoon/a-guide-to-knn-imputation-95e2dc496e">A Guide to KNN Imputation</a>
# </td>
# </tr>
# <td>
# scikit learn:
# </td>
# <td>
# <a href="https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_classification.html">make_classification</a>
# </td>
# </tr>
# </table>

# %% [markdown]
# # XGBoost Classifier

# %% [markdown]
# Import required libraries

# %%
import xgboost as xgb
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 5
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.metrics import accuracy_score
# ----> 5 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Split
X, y = make_classification(
    n_samples=1000, n_features=20, n_informative=10, n_redundant=8, random_state=42
)

# %%
X
